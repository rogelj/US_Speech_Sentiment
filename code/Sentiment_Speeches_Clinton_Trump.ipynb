# %% [markdown]
# # Sentiment in US Politics
#
# Author: **Dr J Rogel-Salazar**
#
# In this notebook we run a straightforward sentiment analysis algorithm over a sample of speeches given by the two major candidates of the 2016 US election, Hillary Clinton and Donald Trump.
#
# The speeches were given in various locations in the US and the text has been left as sourced by Nick Root.

# %%
# %pylab inline
import pandas as pd
import re
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
speeches = pd.read_csv('../Speeches/Speeches_Metadata.csv', na_values="")
speeches.replace(np.nan,' ', regex=True, inplace=1)

# %%
speeches.head()
# Out:
#    Speech_ID Speaker      Date      Location 1     Location 2 Event type  \
# 0          1      HC  01/08/16           Omaha       Nebraska
# 1          2      HC  03/08/16   Commerce City       Colorado     Speech
# 2          3      HC  04/08/16       Las Vegas         Nevada     Speech
# 3          4      HC  05/08/16                  Washington DC     Speech
# 4          5      HC  08/08/16  St. Petersburg        Florida     Speech
#
#   Comment                         File
# 0     Use     01_HC_20160801_Omaha.txt
# 1     Use  02_HC_20160803_Colorado.txt
# 2     Use     03_HC_20160804_Vegas.txt
# 3     Use      04_HC_20160805_Wash.txt
# 4     Use   05_HC_20160808_StPetes.txt

# %%
sp = speeches[speeches['Comment']=="Use"]
sp.is_copy = False

# %%
fnames = "../Speeches/" + sp['Speaker'] + '/' + sp["File"]

# %% [markdown]
# # Sentiment
#
# In this example we create a straightforward sentiment analysis based on individual words used. More complex information can be extracted by looking a combination of words (bigrams for example), but for the purposes of this demo it will suffice to look at monograms.

# %%
from string import punctuation

fsentim = ['positive.txt', 'negative.txt',]

# %%
# Getting th positive and negative words
pos_sent = open(fsentim[0]).read()
positive_words = pos_sent.split('\n')

neg_sent = open(fsentim[1]).read()
negative_words = neg_sent.split('\n')

# %% [markdown]
# Adding a list of stop words in English

# %%
from nltk.corpus import stopwords
stopset = set(stopwords.words('english'))
 
def stopword_filter(words):
    return [word for word in words if word not in stopset]

# %% [markdown]
# # Using a word count approach

# %%
#fname = "../Speeches/HC/01_HC_20160801_Omaha.txt"
#fname = "../Speeches/DT/21_DT_20160831_Everett.txt"

pos_avg = []
neg_avg = []

for fname in fnames:
    positive_counts = []
    negative_counts = []

    with open(fname, encoding="latin") as infile:

        for line in infile:
            lline = line.lower()
            for p in list(punctuation):
                lline = lline.replace(p, '')
            
            re.sub('\s+', ' ', lline).strip()

            words = lline.split(' ')
            mwords = stopword_filter(words)
            word_count = len(mwords)
            

            positive_counter=0
            negative_counter=0
            for word in words:
                #print word
                if word in positive_words:
                    positive_counter += 1
                elif word in negative_words:
                    negative_counter += 1
            # print(positive_counter, negative_counter)
            # print(words)

            positive_counts.append(positive_counter/word_count)
            negative_counts.append(negative_counter/word_count)
            # print("=====")
            # print(positive_counts)

        pos_avg.append(np.mean(positive_counts))
        neg_avg.append(np.mean(negative_counts))

# %%
sp['positive_avg']=pos_avg

# %%
sp['negative_avg']=neg_avg

# %%
sp
# Out:
#     Speech_ID Speaker      Date      Location 1  \
# 0           1      HC  01/08/16           Omaha
# 1           2      HC  03/08/16   Commerce City
# 2           3      HC  04/08/16       Las Vegas
# 3           4      HC  05/08/16
# 4           5      HC  08/08/16  St. Petersburg
# 5           6      HC  11/08/16          Warren
# 6           7      HC  25/08/16            Reno
# 7           8      HC  31/08/16      Cincinnati
# 8           9      HC  08/09/16     Kansas City
# 9          10      HC  08/09/16      Charlotte
# 10         11      HC  15/09/16
# 11         12      HC  16/09/16
# 12         13      HC  16/09/16
# 13         14      HC  17/09/16
# 14         15      HC  19/09/16    Philadelphia
# 15         16      HC  21/09/16         Orlando
# 16         17      HC  30/09/16  Port St. Lucie
# 17         18      HC  02/10/16      Charlotte
# 18         19      HC  11/10/16           Miami
# 19         20      HC  31/10/16      Cincinnati
# 20         21      DT  31/08/16         Phoenix
# 21         22      DT  31/08/16         Phoenix
# 22         23      DT  07/09/16
# 23         24      DT  15/09/16   New York City
# 24         25      DT  03/10/16
# 25         26      DT  04/10/16
# 26         27      DT  05/10/16
# 27         28      DT  12/10/16
# 28         29      DT  13/10/16
# 29         30      DT  15/10/16
# 30         31      DT  17/10/16
# 31         32      DT  18/10/16
# 32         33      DT  21/10/16
# 33         34      DT  25/10/16
# 34         35      DT  26/10/16       Charlotte
# 35         36      DT  27/10/16
# 36         37      DT  29/10/16
# 37         38      DT  29/10/16
# 38         39      DT  30/10/16
# 39         40      DT  31/10/16
#
#                                   Location 2 Event type Comment  \
# 0                                   Nebraska                Use
# 1                                   Colorado     Speech     Use
# 2                                     Nevada     Speech     Use
# 3                              Washington DC     Speech     Use
# 4                                    Florida     Speech     Use
# 5                                   Michigan     Speech     Use
# 6                                     Nevada     Speech     Use
# 7                                       Ohio     Speech     Use
# 8                                   Missouri     Speech     Use
# 9                             North Carolina      Rally     Use
# 10  Congressional Hispanic Caucus Institute      Speech     Use
# 11                             Washington DC     Speech     Use
# 12                             Greensboro NC     Speech     Use
# 13                             Washington DC     Dinner     Use
# 14                                               Speech     Use
# 15                                   Florida     Speech     Use
# 16                                   Florida     Speech     Use
# 17                            North Carolina     Speech     Use
# 18                                   Florida      Rally     Use
# 19                                      Ohio      Rally     Use
# 20                                   Everett                Use
# 21                                   Arizona     Speech     Use
# 22                              Philadelphia                Use
# 23                                  New York     Speech     Use
# 24                                  Colorado                Use
# 25                                   Arizona     Speech     Use
# 26                                    Nevada     Speech     Use
# 27                                  Columbus     Speech     Use
# 28                                   Florida     Speech     Use
# 29                             New Hampshire     Speech     Use
# 30                                 Wisconsin     Speech     Use
# 31                                  Colorado     Speech     Use
# 32                              Pennsylvania     Speech     Use
# 33                                   Florida     Speech     Use
# 34                            North Carolina     Speech     Use
# 35                                      Ohio     Speech     Use
# 36                                   Arizona     Speech     Use
# 37                                  Colarado     Speech     Use
# 38                                    Nevada     Speech     Use
# 39                                  Michigan     Speech     Use
#
#                                File  positive_avg  negative_avg
# 0          01_HC_20160801_Omaha.txt      0.080675      0.026952
# 1       02_HC_20160803_Colorado.txt      0.084656      0.027000
# 2          03_HC_20160804_Vegas.txt      0.084236      0.031590
# 3           04_HC_20160805_Wash.txt      0.095298      0.041599
# 4        05_HC_20160808_StPetes.txt      0.081986      0.020593
# 5         06_HC_20160811_Warren.txt      0.105439      0.032817
# 6           07_HC_20160825_Reno.txt      0.082305      0.058526
# 7            08_HC_20160831_Cin.txt      0.113955      0.044439
# 8          09_HC_20160908_Charl.txt      0.089276      0.035332
# 9             10_HC_20160908_KC.txt      0.125443      0.046042
# 10          11_HC_20160915_CHCI.txt      0.077151      0.046028
# 11        12_HC_20160916_Greens.txt      0.087585      0.045714
# 12          13_HC_20160916_Wash.txt      0.085755      0.040524
# 13          14_HC_20160917_Wash.txt      0.084818      0.038082
# 14          15_HC_20160919_Phil.txt      0.103884      0.053973
# 15           16_HC_20160921_Orl.txt      0.097503      0.030627
# 16           17_HC_20160930_PSL.txt      0.100128      0.022390
# 17         18_HC_20161002_Charl.txt      0.098065      0.053530
# 18            19_HC_20161011_Fl.txt      0.088241      0.044665
# 19           20_HC_20161031_Cin.txt      0.088631      0.051797
# 20       21_DT_20160831_Everett.txt      0.122338      0.051914
# 21       22_DT_20160831_Phoenix.txt      0.107095      0.045106
# 22  23_DT_20160907_Philadelphia.txt      0.136079      0.036070
# 23            24_DT_20160915_NY.txt      0.101379      0.029158
# 24      25_DT_20161003_Colorado.txt      0.080218      0.051389
# 25       26_DT_20161004_Arizona.txt      0.075480      0.032127
# 26        27_DT_20161005_Nevada.txt      0.080266      0.028947
# 27      28_DT_20161012_Columbus.txt      0.032806      0.014200
# 28       29_DT_20161013_Florida.txt      0.111431      0.084809
# 29  30_DT_20161015_NewHampshire.txt      0.103199      0.052319
# 30     31_DT_20161017_Wisconsin.txt      0.104690      0.050442
# 31      32_DT_20161018_Colorado.txt      0.107601      0.056175
# 32  33_DT_20161021_Pennsylvania.txt      0.129916      0.040350
# 33       34_DT_20161025_Florida.txt      0.053302      0.019691
# 34     35_DT_20161026_Charlotte.txt      0.107266      0.046511
# 35          36_DT_20161027_Ohio.txt      0.096262      0.041966
# 36       37_DT_20161029_Arizona.txt      0.106876      0.078256
# 37      38_DT_20161029_Colorado.txt      0.071941      0.085858
# 38        39_DT_20161030_Nevada.txt      0.108264      0.056415
# 39      40_DT_20161031_Michigan.txt      0.101658      0.049699

# %% [markdown]
# # Let us use TextBlob for sentiment analysis

# %%
from textblob import TextBlob

# %%
# fname = "../Speeches/HC/01_HC_20160801_Omaha.txt"
# fname = "../Speeches/DT/21_DT_20160831_Everett.txt"

sentiment = []
subjectivity = []

for fname in fnames:

    with open(fname, 'r', encoding="latin") as infile:
        content = infile.read()

        blob = TextBlob(content)

        sentiment.append(blob.sentiment.polarity)
        subjectivity.append(blob.sentiment.subjectivity)

    #     for sentence in blob.sentences:
    #         print(sentence.sentiment)

# %%
sp['sentiment']=sentiment
sp['subjectivity']=subjectivity

# %%
sp.head()
# Out:
#    Speech_ID Speaker      Date      Location 1     Location 2 Event type  \
# 0          1      HC  01/08/16           Omaha       Nebraska
# 1          2      HC  03/08/16   Commerce City       Colorado     Speech
# 2          3      HC  04/08/16       Las Vegas         Nevada     Speech
# 3          4      HC  05/08/16                  Washington DC     Speech
# 4          5      HC  08/08/16  St. Petersburg        Florida     Speech
#
#   Comment                         File  positive_avg  negative_avg  sentiment  \
# 0     Use     01_HC_20160801_Omaha.txt      0.080675      0.026952   0.152623
# 1     Use  02_HC_20160803_Colorado.txt      0.084656      0.027000   0.168907
# 2     Use     03_HC_20160804_Vegas.txt      0.084236      0.031590   0.171133
# 3     Use      04_HC_20160805_Wash.txt      0.095298      0.041599   0.122291
# 4     Use   05_HC_20160808_StPetes.txt      0.081986      0.020593   0.141604
#
#    subjectivity
# 0      0.444259
# 1      0.482505
# 2      0.424460
# 3      0.439891
# 4      0.476870

# %%
psp = sp.groupby(['Speaker'])

# %%
import seaborn as sns
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(10, 6))

# Plot the sentiment
sns.barplot(x="Speech_ID", y="sentiment", hue='Speaker', data=sp, palette=sns.color_palette("RdBu_r", 2))

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlabel="Speech")
ax.set(ylabel="Sentiment")
# sns.despine(left=True, bottom=True)
